# %%
# Conditional Statement

# %%
age = input("input you age:\n")
adult = "Ypu are an adut"
child = "you are a child"
if age > 18:
    print(adult)

# %%
food_items = ["potato", "rice", "onion", "beans"]
prices = [500, 1700, 1200, 1000]

# %%
if food_items[0] == "tomato":
    prices.append(10000)
elif food_items[0] == "potato":
    prices.append(20000)
else:
    print("No extra cost for the first item")
print(prices)
# Out:
# [500, 1700, 1200, 1000, 20000]

# %%
if food_items[2] == "onion":
    prices.append(30000)
